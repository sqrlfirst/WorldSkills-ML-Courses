# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('beauty.csv', )
df.head()
# Out:
#     wage  exper  union  goodhlth  black  female  married  service  educ  looks
# 0   5.73     30      0         1      0       1        1        1    14      4
# 1   4.28     28      0         1      0       1        1        0    12      3
# 2   7.96     35      0         1      0       1        0        0    10      4
# 3  11.57     38      0         1      0       0        1        1    16      3
# 4  11.42     27      0         1      0       0        1        0    16      3

# %%
plt.figure(figsize=(10,15))
for ind, col in enumerate(df.columns):
    plt.subplots(3,4)

# %%
sns.countplot(df["female"])
# Out:
# <AxesSubplot:xlabel='female', ylabel='count'>

# %%
sns.violinplot(data=df, y="exper", x="looks")
# Out:
# <AxesSubplot:xlabel='looks', ylabel='exper'>

# %%
df.corr()
# Out:
#               wage     exper     union  goodhlth     black    female  \
# wage      1.000000  0.234632  0.094529  0.006756 -0.059052 -0.313419
# exper     0.234632  1.000000  0.089792 -0.131609  0.007566 -0.247209
# union     0.094529  0.089792  1.000000 -0.022398  0.031939 -0.100037
# goodhlth  0.006756 -0.131609 -0.022398  1.000000 -0.034073 -0.039684
# black    -0.059052  0.007566  0.031939 -0.034073  1.000000  0.113703
# female   -0.313419 -0.247209 -0.100037 -0.039684  0.113703  1.000000
# married   0.184521  0.255607  0.053629 -0.013315 -0.133306 -0.319228
# service  -0.053653 -0.057328 -0.103633  0.049947  0.017261  0.267961
# educ      0.212333 -0.186200 -0.096022  0.107129 -0.138157  0.009105
# looks     0.055019 -0.155035 -0.043495  0.058558  0.012098  0.017129
#
#            married   service      educ     looks
# wage      0.184521 -0.053653  0.212333  0.055019
# exper     0.255607 -0.057328 -0.186200 -0.155035
# union     0.053629 -0.103633 -0.096022 -0.043495
# goodhlth -0.013315  0.049947  0.107129  0.058558
# black    -0.133306  0.017261 -0.138157  0.012098
# female   -0.319228  0.267961  0.009105  0.017129
# married   1.000000 -0.075082 -0.047674 -0.064636
# service  -0.075082  1.000000  0.301628  0.010213
# educ     -0.047674  0.301628  1.000000  0.153842
# looks    -0.064636  0.010213  0.153842  1.000000

# %%
sns.heatmap(df.corr(), annot=True, fmt=".3f")
# Out:
# <AxesSubplot:>

# %%
telecom = pd.read_csv("telecom_churn.csv")

# %%
telecom.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-1712cad512bd> in <module>
# ----> 1 pd.value_counts(telecom)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/algorithms.py in value_counts(values, sort, ascending, normalize, bins, dropna)
#     771
#     772         else:
# --> 773             keys, counts = _value_counts_arraylike(values, dropna)
#     774
#     775             result = Series(counts, index=keys, name=name)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/algorithms.py in _value_counts_arraylike(values, dropna)
#     797     counts : np.ndarray
#     798     """
# --> 799     values = _ensure_arraylike(values)
#     800     original = values
#     801     values, _ = _ensure_data(values)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/algorithms.py in _ensure_arraylike(values)
#     220             if isinstance(values, tuple):
#     221                 values = list(values)
# --> 222             values = construct_1d_object_array_from_listlike(values)
#     223         else:
#     224             values = np.asarray(values)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in construct_1d_object_array_from_listlike(values)
#    1589     # making a 1D array that contains list-likes is a bit tricky:
#    1590     result = np.empty(len(values), dtype="object")
# -> 1591     result[:] = values
#    1592     return result
#    1593
#
# ValueError: could not broadcast input array from shape (3333,20) into shape (3333)
