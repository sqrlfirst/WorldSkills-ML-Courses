# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount = True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #Как будем сравнивать различные методы?

# %%
import pandas as pd
import numpy as np
import random
import collections

import matplotlib.pyplot as plt
import seaborn as sns

# %%
def insert_NA(df, per):
  replaced = collections.defaultdict(set)
  ix = [(row, col) for row in range(df.shape[0]) for col in range(df.shape[1])]
  random.shuffle(ix)
  to_replace = int(round(per*len(ix)))
  for row, col in ix:
    if len(replaced[row]) < df.shape[1] - 1:
      df.iloc[row, col] = np.nan
      to_replace -= 1
      replaced[row].add(col)
      if to_replace == 0:
        break
  
  return(df)

# %%
def MAE(actual, missing, imputation):
  mask = missing.isna()
  return(abs(actual[mask] - imputation[mask]).sum().sum() / mask.sum().sum())

# %%
dataset = pd.read_csv("/content/gdrive/MyDrive/ML/Datasets/Breast Cancer Wisconsin (Diagnostic).csv")

# %%
dataset.head()
# Out:
#   diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0         M        17.99  ...          0.4601                  0.11890
# 1         M        20.57  ...          0.2750                  0.08902
# 2         M        19.69  ...          0.3613                  0.08758
# 3         M        11.42  ...          0.6638                  0.17300
# 4         M        20.29  ...          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
dataset = dataset.drop(["diagnosis"], axis = 1)

# %%
dataset.describe().T
# Out:
#                          count        mean  ...          75%         max
# radius_mean              569.0   14.127292  ...    15.780000    28.11000
# texture_mean             569.0   19.289649  ...    21.800000    39.28000
# perimeter_mean           569.0   91.969033  ...   104.100000   188.50000
# area_mean                569.0  654.889104  ...   782.700000  2501.00000
# smoothness_mean          569.0    0.096360  ...     0.105300     0.16340
# compactness_mean         569.0    0.104341  ...     0.130400     0.34540
# concavity_mean           569.0    0.088799  ...     0.130700     0.42680
# concave points_mean      569.0    0.048919  ...     0.074000     0.20120
# symmetry_mean            569.0    0.181162  ...     0.195700     0.30400
# fractal_dimension_mean   569.0    0.062798  ...     0.066120     0.09744
# radius_se                569.0    0.405172  ...     0.478900     2.87300
# texture_se               569.0    1.216853  ...     1.474000     4.88500
# perimeter_se             569.0    2.866059  ...     3.357000    21.98000
# area_se                  569.0   40.337079  ...    45.190000   542.20000
# smoothness_se            569.0    0.007041  ...     0.008146     0.03113
# compactness_se           569.0    0.025478  ...     0.032450     0.13540
# concavity_se             569.0    0.031894  ...     0.042050     0.39600
# concave points_se        569.0    0.011796  ...     0.014710     0.05279
# symmetry_se              569.0    0.020542  ...     0.023480     0.07895
# fractal_dimension_se     569.0    0.003795  ...     0.004558     0.02984
# radius_worst             569.0   16.269190  ...    18.790000    36.04000
# texture_worst            569.0   25.677223  ...    29.720000    49.54000
# perimeter_worst          569.0  107.261213  ...   125.400000   251.20000
# area_worst               569.0  880.583128  ...  1084.000000  4254.00000
# smoothness_worst         569.0    0.132369  ...     0.146000     0.22260
# compactness_worst        569.0    0.254265  ...     0.339100     1.05800
# concavity_worst          569.0    0.272188  ...     0.382900     1.25200
# concave points_worst     569.0    0.114606  ...     0.161400     0.29100
# symmetry_worst           569.0    0.290076  ...     0.317900     0.66380
# fractal_dimension_worst  569.0    0.083946  ...     0.092080     0.20750
#
# [30 rows x 8 columns]

# %%
dataset.isna().sum()
# Out:
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
data_NA = insert_NA(dataset.copy(), 0.03)
data_NA.head()
# Out:
#    radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0        17.99           NaN  ...          0.4601                  0.11890
# 1        20.57         17.77  ...          0.2750                  0.08902
# 2        19.69         21.25  ...          0.3613                  0.08758
# 3        11.42         20.38  ...          0.6638                  0.17300
# 4        20.29         14.34  ...          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
data_NA.shape
# Out:
# (569, 30)

# %%
data_NA.isna().sum()
# Out:
# radius_mean                20
# texture_mean               18
# perimeter_mean             15
# area_mean                  21
# smoothness_mean            22
# compactness_mean           20
# concavity_mean             14
# concave points_mean        10
# symmetry_mean              14
# fractal_dimension_mean     16
# radius_se                  12
# texture_se                 23
# perimeter_se               13
# area_se                    15
# smoothness_se              14
# compactness_se             19
# concavity_se               21
# concave points_se          13
# symmetry_se                24
# fractal_dimension_se       20
# radius_worst               19
# texture_worst              16
# perimeter_worst            20
# area_worst                 16
# smoothness_worst           16
# compactness_worst          17
# concavity_worst            18
# concave points_worst       14
# symmetry_worst             13
# fractal_dimension_worst    19
# dtype: int64

# %%
data_NA.isnull().mean().sort_values(ascending = False)
# Out:
# symmetry_se                0.042179
# texture_se                 0.040422
# smoothness_mean            0.038664
# area_mean                  0.036907
# concavity_se               0.036907
# radius_mean                0.035149
# fractal_dimension_se       0.035149
# compactness_mean           0.035149
# perimeter_worst            0.035149
# compactness_se             0.033392
# fractal_dimension_worst    0.033392
# radius_worst               0.033392
# texture_mean               0.031634
# concavity_worst            0.031634
# compactness_worst          0.029877
# smoothness_worst           0.028120
# fractal_dimension_mean     0.028120
# area_worst                 0.028120
# texture_worst              0.028120
# area_se                    0.026362
# perimeter_mean             0.026362
# symmetry_mean              0.024605
# concavity_mean             0.024605
# concave points_worst       0.024605
# smoothness_se              0.024605
# perimeter_se               0.022847
# concave points_se          0.022847
# symmetry_worst             0.022847
# radius_se                  0.021090
# concave points_mean        0.017575
# dtype: float64

# %%
from sklearn.impute import SimpleImputer

# %%
sumple_imp = SimpleImputer(missing_values = np.nan, strategy = 'constant', fill_value = 0)

# %%
data_NA_zero = sumple_imp.fit_transform(data_NA)
data_NA_zero = pd.DataFrame(data_NA_zero, columns = data_NA.columns)

# %%
data_NA_zero.head()
# Out:
#    radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0        17.99          0.00  ...          0.4601                  0.11890
# 1        20.57         17.77  ...          0.2750                  0.08902
# 2        19.69         21.25  ...          0.3613                  0.08758
# 3        11.42         20.38  ...          0.6638                  0.17300
# 4        20.29         14.34  ...          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
data_NA_zero.isna().sum()
# Out:
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
zero_mae = MAE(dataset, data_NA, data_NA_zero)
zero_mae
# Out:
# 64.22786784765628

# %% [markdown]
# #Удаление неполных векторов

# %%
data_NA.isna().sum()
# Out:
# radius_mean                164
# texture_mean               174
# perimeter_mean             172
# area_mean                  159
# smoothness_mean            164
# compactness_mean           182
# concavity_mean             154
# concave points_mean        187
# symmetry_mean              187
# fractal_dimension_mean     162
# radius_se                  174
# texture_se                 165
# perimeter_se               175
# area_se                    170
# smoothness_se              164
# compactness_se             182
# concavity_se               172
# concave points_se          165
# symmetry_se                162
# fractal_dimension_se       158
# radius_worst               167
# texture_worst              167
# perimeter_worst            201
# area_worst                 172
# smoothness_worst           184
# compactness_worst          173
# concavity_worst            168
# concave points_worst       148
# symmetry_worst             171
# fractal_dimension_worst    178
# dtype: int64

# %%
data_NA.shape
# Out:
# (569, 30)

# %%
data_NA.dropna().shape
# Out:
# (0, 30)

# %%
data_NA.dropna(axis = 1).shape
# Out:
# (569, 0)

# %%
# отбросить строки, только если все столбцы содержат NaN
data_NA.dropna(how = 'all').shape
# Out:
# (569, 30)

# %%
# отбросить строки, если в них менее 4 значений не NaN
data_NA.dropna(thresh = 4).shape
# Out:
# (569, 30)

# %%
# отбросить столбцы, если в них менее 10 значений не NaN
data_NA.dropna(thresh = 10, axis = 1).shape
# Out:
# (569, 30)

# %% [markdown]
# #SimpleImputer:

# %%
from sklearn.impute import SimpleImputer

# %% [markdown]
# ##Среднее арифметическое

# %%
sumple_imp = SimpleImputer(missing_values = np.nan, strategy = 'mean')

# %%
data_NA_mean = sumple_imp.fit_transform(data_NA)
data_NA_mean = pd.DataFrame(data_NA_mean, columns = data_NA.columns)

# %%
data_NA_mean.head()
# Out:
#    radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0        17.99     19.248149  ...          0.4601                  0.11890
# 1        20.57     17.770000  ...          0.2750                  0.08902
# 2        19.69     21.250000  ...          0.3613                  0.08758
# 3        11.42     20.380000  ...          0.6638                  0.17300
# 4        20.29     14.340000  ...          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
data_NA_mean.isna().sum()
# Out:
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
mean_mae = MAE(dataset, data_NA, data_NA_mean)
mean_mae
# Out:
# 24.63672132911663

# %% [markdown]
# ##Медиана

# %%
# %%time
sumple_imp = SimpleImputer(missing_values = np.nan, strategy = 'median')

data_NA_median = sumple_imp.fit_transform(data_NA)
data_NA_median = pd.DataFrame(data_NA_median, columns = data_NA.columns)
# Out:
# CPU times: user 5.75 ms, sys: 1 ms, total: 6.75 ms
# Wall time: 7.8 ms

# %%
data_NA_median.isna().sum()
# Out:
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
data_NA_mean.head()
# Out:
#    radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0        17.99     19.248149  ...          0.4601                  0.11890
# 1        20.57     17.770000  ...          0.2750                  0.08902
# 2        19.69     21.250000  ...          0.3613                  0.08758
# 3        11.42     20.380000  ...          0.6638                  0.17300
# 4        20.29     14.340000  ...          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
median_mae = MAE(dataset, data_NA, data_NA_median)
median_mae
# Out:
# 22.595794021484377

# %% [markdown]
# ##Мода

# %%
sumple_imp = SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')

data_NA_moda = sumple_imp.fit_transform(data_NA)
data_NA_moda = pd.DataFrame(data_NA_moda, columns = data_NA.columns)

# %%
moda_mae = MAE(dataset, data_NA, data_NA_moda)
moda_mae
# Out:
# 34.77742653124999

# %% [markdown]
# #Multivariate feature imputation

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %% [markdown]
# ## Iterative Imputer (RandomForestRegressor)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
imp_iter = IterativeImputer(missing_values = np.nan, estimator = RandomForestRegressor())

# %%
# %%time
data_NA_rf = imp_iter.fit_transform(data_NA)
data_NA_rf = pd.DataFrame(data_NA_rf, columns = data_NA.columns)
# Out:
# CPU times: user 1min 37s, sys: 331 ms, total: 1min 37s
# Wall time: 1min 37s

# %%
data_NA_rf.isna().sum()
# Out:
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
data_NA_rf.head()
# Out:
#    radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0        17.99       14.0577  ...          0.4601                  0.11890
# 1        20.57       17.7700  ...          0.2750                  0.08902
# 2        19.69       21.2500  ...          0.3613                  0.08758
# 3        11.42       20.3800  ...          0.6638                  0.17300
# 4        20.29       14.3400  ...          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
rf_mae = MAE(dataset, data_NA, data_NA_rf)
rf_mae
# Out:
# 1.4574557139145143

# %% [markdown]
# ##MissForest

# %%
# !pip install missingpy
from missingpy import MissForest
# Out:
# Requirement already satisfied: missingpy in /usr/local/lib/python3.6/dist-packages (0.2.0)

# %%
imputer = MissForest()

# %%
# %%time
data_NA_miss_forest = imputer.fit_transform(data_NA)
data_NA_miss_forest = pd.DataFrame(data_NA_miss_forest, columns = data_NA.columns)
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# CPU times: user 3min 38s, sys: 3.72 s, total: 3min 42s
# Wall time: 2min 23s

# %%
miss_forest_mae = MAE(dataset, data_NA, data_NA_miss_forest)
miss_forest_mae
# Out:
# 1.3614931018943357

# %% [markdown]
# ##KNNImputer

# %%
from sklearn.impute import KNNImputer

# %%
imputer = KNNImputer(n_neighbors = 5, weights = "uniform")

# %%
data_NA_KNNImputer = imputer.fit_transform(data_NA)
data_NA_KNNImputer = pd.DataFrame(data_NA_KNNImputer, columns = data_NA.columns)

# %%
knn_mae = MAE(dataset, data_NA, data_NA_KNNImputer)
knn_mae
# Out:
# 4.224608857031248

# %% [markdown]
# #Сравниваем методы

# %%
list_mae = [zero_mae, mean_mae, median_mae, moda_mae, rf_mae, miss_forest_mae, knn_mae]

methods = ['Zero', 'Mean', 'Median', 'Moda', 'Random Forest', 'Miss Forest', 'KNN']

# %%
sns.set(font_scale = 1.5)
f, ax = plt.subplots(figsize=(10, 5))
sns.barplot(y = methods, x = list_mae, palette = 'pastel', orient = 'h');

# %% [markdown]
# #Восстановление пропущенных значений в данных смешанного типа

# %%
# !pip install missingpy
from missingpy import MissForest
from collections import defaultdict
from sklearn.preprocessing import LabelEncoder
import copy

# %%
path = "/content/gdrive/MyDrive/ML/Datasets/adult.csv"            # Иногда могут быть проблемы с кирилицей в названиях папок на пути к файлу, постарайтесь всегда использовтаь только латиницу.
data = pd.read_csv(path, sep = ",")                               # Путь к файлу можно записать как отдельно, так и внутри метода read_csv.

# %%
data.head()
# Out:
#    age     workclass  fnlwgt  ... hours.per.week  native.country income
# 0   90  Never-worked   77053  ...             40   United-States  <=50K
# 1   82       Private  132870  ...             18   United-States  <=50K
# 2   66  Never-worked  186061  ...             40   United-States  <=50K
# 3   54       Private  140359  ...             40   United-States  <=50K
# 4   41       Private  264663  ...             40   United-States  <=50K
#
# [5 rows x 15 columns]

# %%
X = data.drop(["income"], axis = 1)

# %%
X.head()
# Out:
#    age     workclass  fnlwgt  ... capital.loss  hours.per.week native.country
# 0   90  Never-worked   77053  ...         4356              40  United-States
# 1   82       Private  132870  ...         4356              18  United-States
# 2   66  Never-worked  186061  ...         4356              40  United-States
# 3   54       Private  140359  ...         3900              40  United-States
# 4   41       Private  264663  ...         3900              40  United-States
#
# [5 rows x 14 columns]

# %%
X.shape
# Out:
# (32561, 14)

# %%
X.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# dtype: int64

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 3.5+ MB

# %%
X_NA = insert_NA(X.copy(), 0.3)
X_NA.head()
# Out:
#     age     workclass    fnlwgt  ... capital.loss  hours.per.week native.country
# 0  90.0  Never-worked       NaN  ...       4356.0            40.0  United-States
# 1  82.0           NaN       NaN  ...       4356.0            18.0  United-States
# 2  66.0  Never-worked       NaN  ...       4356.0            40.0            NaN
# 3   NaN       Private  140359.0  ...          NaN             NaN  United-States
# 4  41.0       Private  264663.0  ...       3900.0            40.0  United-States
#
# [5 rows x 14 columns]

# %%
imp_iter2 = IterativeImputer(missing_values = np.nan, estimator = RandomForestClassifier())

# %%
# %%time
data_NA_rf = imp_iter2.fit_transform(res_X)

# %%
X_NA.isna().sum()
# Out:
# age               9830
# workclass         9758
# fnlwgt            9701
# education         9719
# education.num     9692
# marital.status    9798
# occupation        9841
# relationship      9759
# race              9671
# sex               9799
# capital.gain      9720
# capital.loss      9818
# hours.per.week    9828
# native.country    9822
# dtype: int64

# %%
def imputation_missing_value(data):
  categorical_feature_list = list(data.select_dtypes(include = 'object').columns)
  int_label = list(data.select_dtypes(include = 'object').columns) + list(data.select_dtypes(include = 'int64').columns)
  encoding_dict = defaultdict(LabelEncoder)

  original = copy.deepcopy(data)
  mask = original.isnull()

  for i in categorical_feature_list:
    data[i][pd.isnull(data[i])] = 'XXX'

  for col in categorical_feature_list:
    le = LabelEncoder()
    le.fit(list(data[col]))
    encoding_dict[col] = le

  for col in categorical_feature_list:
    data[col] = encoding_dict[col].transform(data[col])

  data = data.where(~mask, original)

  imputer = MissForest()
  cat_vars = [data.columns.get_loc(c) for c in categorical_feature_list if c in data]
  data_imputed = imputer.fit_transform(data, cat_vars)
  data_imputed = pd.DataFrame(data_imputed, columns = data.columns)

  for i in int_label:
    data_imputed[i] = data_imputed[i].astype(int)

  for col in categorical_feature_list:
    data_imputed[col] = encoding_dict[col].inverse_transform(data_imputed[col])

  return(data_imputed)

# %%
# %%time
X_miss_forest = imputation_missing_value(X_NA)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4

# %%
X_miss_forest
# Out:
#          age     workclass  ...  hours.per.week       native.country
# 0      90.00  Never-worked  ...           40.00        United-States
# 1      50.58       Private  ...           18.00      Trinadad&Tobago
# 2      44.65  Never-worked  ...           40.00        United-States
# 3      54.00       Private  ...           40.00        United-States
# 4      41.00       Private  ...           40.00  Rare native.country
# ...      ...           ...  ...             ...                  ...
# 32556  29.96       Private  ...           40.33        United-States
# 32557  34.52       Private  ...           38.00                South
# 32558  40.00       Private  ...           40.45        United-States
# 32559  58.00       Private  ...           35.94      Trinadad&Tobago
# 32560  20.40       Private  ...           20.00        United-States
#
# [32561 rows x 14 columns]

# %%
X_miss_forest.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# dtype: int64
